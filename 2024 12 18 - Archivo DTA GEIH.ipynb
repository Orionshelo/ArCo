# %%
import pandas as pd

# %%
"""
columnas = [
    '',
    ''
]
"""
# Características Generales 2022
caracteristicas_generales_22_1 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación1_22.dta')
caracteristicas_generales_22_2 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación2_22.dta')
caracteristicas_generales_22_3 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación3_22.dta')
caracteristicas_generales_22_4 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación4_22.dta')
caracteristicas_generales_22_5 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación5_22.dta')
caracteristicas_generales_22_6 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación6_22.dta')
caracteristicas_generales_22_7 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación7_22.dta')
caracteristicas_generales_22_8 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación8_22.dta')
caracteristicas_generales_22_9 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación9_22.dta')
caracteristicas_generales_22_10 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación10_22.dta')
caracteristicas_generales_22_11 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación11_22.dta')
caracteristicas_generales_22_12 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación12_22.dta')


# Características Generales 2023
caracteristicas_generales_23_1 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación1_23.dta')
caracteristicas_generales_23_2 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación2_23.dta')
caracteristicas_generales_23_3 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación3_23.dta')
caracteristicas_generales_23_4 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación4_23.dta')
caracteristicas_generales_23_5 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación5_23.dta')
caracteristicas_generales_23_6 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación6_23.dta')
caracteristicas_generales_23_7 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación7_23.dta')
caracteristicas_generales_23_8 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación8_23.dta')
caracteristicas_generales_23_9 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación9_23.dta')
caracteristicas_generales_23_10 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación10_23.dta')
caracteristicas_generales_23_11= pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación11_23.dta')
caracteristicas_generales_23_12 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Características generales, seguridad social en salud y educación12_23.dta')

# Ocupados 2022

ocupados_22_1 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados1_22.dta')
ocupados_22_2 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados2_22.dta')
ocupados_22_3 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados3_22.dta')
ocupados_22_4 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados4_22.dta')
ocupados_22_5 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados5_22.dta')
ocupados_22_6 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados6_22.dta')
ocupados_22_7 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados7_22.dta')
ocupados_22_8 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados8_22.dta')
ocupados_22_9 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados9_22.dta')
ocupados_22_10 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados10_22.dta')
ocupados_22_11 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados11_22.dta')
ocupados_22_12 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados12_22.dta')

# Ocupados 2023

ocupados_23_1 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados1_23.dta')
ocupados_23_2 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados2_23.dta')
ocupados_23_3 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados3_23.dta')
ocupados_23_4 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados4_23.dta')
ocupados_23_5 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados5_23.dta')
ocupados_23_6 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados6_23.dta')
ocupados_23_7 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados7_23.dta')
ocupados_23_8 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados8_23.dta')
ocupados_23_9 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados9_23.dta')
ocupados_23_10 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados10_23.dta')
ocupados_23_11 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados11_23.dta')
ocupados_23_12 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/Ocupados12_23.dta')


# Factor Departamental 2022

total_22 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/TOTAL_22.dta')

# Factor Departamental 2023

total_23 = pd.read_stata('C:/Users/supegui/Documents/IDIC/Excel/GEIH/TOTAL_23.dta')

# %%
base_2022 = pd.concat([caracteristicas_generales_22_1, caracteristicas_generales_22_2], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_3], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_4], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_5], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_6], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_7], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_8], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_9], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_10], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_11], axis=0)
base_2022 = pd.concat([base_2022, caracteristicas_generales_22_12], axis=0)


base_2022_x = pd.concat([ocupados_22_1, ocupados_22_2], axis=0)
base_2022_x = pd.concat([base_2022_x, ocupados_22_3], axis=0)
base_2022_x = pd.concat([base_2022_x, ocupados_22_4], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_5], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_6], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_7], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_8], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_9], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_10], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_11], axis=0)
base_2022_x  = pd.concat([base_2022_x, ocupados_22_12], axis=0)


#base_2022
base_2022_x
# Out:
#        DIRECTORIO  SECUENCIA_P  ORDEN  HOGAR  \
# 0       5000000.0          1.0    1.0    1.0
# 1       5000001.0          1.0    1.0    1.0
# 2       5000001.0          1.0    2.0    1.0
# 3       5000001.0          1.0    3.0    1.0
# 4       5000002.0          1.0    1.0    1.0
# ...           ...          ...    ...    ...
# 30500   7309048.0          1.0    2.0    1.0
# 30501   7309048.0          1.0    3.0    1.0
# 30502   7309049.0          1.0    1.0    1.0
# 30503   7309050.0          1.0    1.0    1.0
# 30504   7309050.0          1.0    2.0    1.0
#
#                                                    P3044  P6440  P6450  P6460  \
# 0                                       AGUA EMBOTELLADA    1.0    1.0    NaN
# 1      SERVICIO DE REPARTO DE VOLANTES PUBLICITARIO A...    1.0    1.0    NaN
# 2                                   DESODORANTE COLONIAS    2.0    NaN    NaN
# 3                  SERVICIO DE DOMICILIOS A PARTICULARES    2.0    NaN    NaN
# ...

# %%
base_ocu_car = pd.merge(base_2022, base_2022_x, on=['OCI'] ,how="outer")
base_ocu_car
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3152\756662642.py in ?()
# ----> 1 base_ocu_car = pd.merge(base_2022, base_2022_x, on=['OCI'] ,how="outer")
#       2 base_ocu_car
#
# c:\Users\supegui\AppData\Local\anaconda3\envs\surprise_env\lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# ...

# %%
#print(ocupados_23_12['OCI'])


#base_2022 = pd.merge(caracteristicas_generales_22_1, ocupados_22_1, on=['OCI'], how="outer")

base_2022_x = pd.merge(caracteristicas_generales_22_1, caracteristicas_generales_22_2, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022_x = pd.merge(base_2022_x, caracteristicas_generales_22_3, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")

base_2022_y = pd.merge(ocupados_22_1, ocupados_22_2, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022_y = pd.merge(base_2022_y, ocupados_22_2, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")

#base_2022_z = pd.merge(base_2022_x, caracteristicas_generales_22_4, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer", suffixes=["_base"])
#base_2022_z = pd.merge(base_2022_z, caracteristicas_generales_22_5, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")

#base_2022_a = pd.merge(base_2022_z, caracteristicas_generales_22_6, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
#base_2022_a = pd.merge(base_2022_a, caracteristicas_generales_22_7, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")





"""
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_4, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_5, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_6, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_7, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_8, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_9, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_10, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_11, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_12, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
"""
# Out:
# '\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_4, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'ORDEN\'], how="outer")\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_5, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'ORDEN\'], how="outer")\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_6, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'ORDEN\'], how="outer")\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_7, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'ORDEN\'], how="outer")\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_8, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'ORDEN\'], how="outer")\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_9, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'ORDEN\'], how="outer")\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_10, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'ORDEN\'], how="outer")\nbase_2022 = pd.merge(base_2022, caracteristicas_generales_22_11, on=[\'DIRECTORIO\', \'SECUENCIA_P\', \'O
# ...

# %%
#print(caracteristicas_generales_22_1)
#print(base_2022_x)
#print(base_2022_y)

base_2022_oci = pd.merge(base_2022_x, base_2022_y, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022_oci

# %%
caracteristicas_generales_22

# %%
# Uniones

# 2022 - Características Generales
base_2022 = pd.merge(caracteristicas_generales_22_1, caracteristicas_generales_22_2, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_3, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_4, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_5, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_6, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_7, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_8, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_9, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_10, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_11, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")
base_2022 = pd.merge(base_2022, caracteristicas_generales_22_12, on=['DIRECTORIO', 'SECUENCIA_P', 'ORDEN'], how="outer")

# %%
# 2022 - Características Generales con Ocupados a la derecha
#base_2022 = pd.merge(base_2022, ocupados_22_1, on=['OCI'], how="right")
#base_2022 = pd.merge(base_2022, ocupados_22_2, on=['OCI'], how="inner", suffixes=('_base', '2'))
#base_2022 = pd.merge(base_2022, ocupados_22_3, on=['OCI'], how="inner", suffixes=('_base', '3'))
#base_2022 = pd.merge(base_2022, ocupados_22_4, on=['OCI'], how="inner", suffixes=('_base', '4'))
#base_2022 = pd.merge(base_2022, ocupados_22_5, on=['OCI'], how="inner", suffixes=('_base', '5'))
#base_2022 = pd.merge(base_2022, ocupados_22_6, on=['OCI'], how="inner", suffixes=('_base', '6'))
#base_2022 = pd.merge(base_2022, ocupados_22_7, on=['OCI'], how="inner", suffixes=('_base', '7'))
#base_2022 = pd.merge(base_2022, ocupados_22_8, on=['OCI'], how="inner", suffixes=('_base', '8'))
#base_2022 = pd.merge(base_2022, ocupados_22_9, on=['OCI'], how="inner", suffixes=('_base', '9'))
#base_2022 = pd.merge(base_2022, ocupados_22_10, on=['OCI'], how="inner", suffixes=('_base', '10'))
#base_2022 = pd.merge(base_2022, ocupados_22_11, on=['OCI'], how="inner", suffixes=('_base', '11'))
#base_2022 = pd.merge(base_2022, ocupados_22_12, on=['OCI'], how="inner", suffixes=('_base', '12'))

# %%
print(base_2022)

# %%
union_geih = pd.merge(geih_1, geih_2, on=["ContentID", "Entidad", "Nombre_Instrumento"], how="outer")
union_geih = pd.merge(union_geih, geih_3, on=["ContentID", "Entidad", "Nombre_Instrumento"], how="outer")

# %%
print(union_geih)

# %%
union_geih.to_excel('C:/Users/supegui/Documents/IDIC/Excel/union_geih.xlsx', index=False)

# %%
union_geih.to_csv('C:/Users/supegui/Documents/IDIC/Excel/union_geih.csv', index=False)
